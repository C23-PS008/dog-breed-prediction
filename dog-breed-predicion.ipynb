# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Embedding, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## 1.  Data Collection

# %%
dataframe = pd.read_csv('./data/akc-data-latest-v1.csv')
dataframe.head()
# Out:
#               breed                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
dataframe.columns.tolist()
# Out:
# ['breed',
#  'description',
#  'temperament',
#  'popularity',
#  'min_height',
#  'max_height',
#  'min_weight',
#  'max_weight',
#  'min_expectancy',
#  'max_expectancy',
#  'group',
#  'grooming_frequency_value',
#  'grooming_frequency_category',
#  'shedding_value',
#  'shedding_category',
#  'energy_level_value',
#  'energy_level_category',
#  'trainability_value',
#  'trainability_category',
#  'demeanor_value',
#  'demeanor_category']

# %% [markdown]
# Kolom "min_expectancy" dan "max_expectancy" mengacu pada harapan hidup minimum dan maksimum dari ras anjing, dengan tahun sebagai unit pengukuran.
#
# Kolom "group" mengacu pada 7 kelompok anjing utama, tetapi ada 2 nilai yang salah untuk "Foundation Stock Service" dan "Miscellaneous Class".

# %%
dataframe['group'].unique().tolist()
# Out:
# ['Toy Group',
#  'Hound Group',
#  'Terrier Group',
#  'Working Group',
#  'Foundation Stock Service',
#  'Non-Sporting Group',
#  'Sporting Group',
#  'Herding Group',
#  'Miscellaneous Class']

# %% [markdown]
# Kolom dengan "_value" pada namanya memiliki nilai 0.2, 0.4, 0.6, 0.8, atau 1. yang sesuai dengan nilai kolom dengan "_category" pada namanya. Angka yang lebih tinggi menunjukkan bahwa ras tersebut memiliki lebih banyak sifat yang dirujuk oleh kolom tersebut. Misalnya, untuk shedding_value, angka yang lebih tinggi berarti breed tersebut lebih sering rontok, yang ditunjukkan oleh shedding_category.

# %%
dataframe[['shedding_value', 'shedding_category']].head()
# Out:
#    shedding_value shedding_category
# 0             0.6          Seasonal
# 1             0.2        Infrequent
# 2             0.4        Occasional
# 3             0.6          Seasonal
# 4             0.6          Seasonal

# %% [markdown]
# ## Menampilkan Kolom Breed

# %%
dataframe['breed'].tolist()
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American English Coonhound',
#  'American Eskimo Dog',
#  'American Foxhound',
#  'American Hairless Terrier',
#  'American Leopard Hound',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Anatolian Shepherd Dog',
#  'Appenzeller Sennenhund',
#  'Australian Cattle Dog',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Stumpy Tail Cattle Dog',
#  'Australian Terrier',
#  'Azawakh',
#  'Barbet',
#  'Basenji',
#  'Basset Fauve de Bretagne',
#  'Basset Hound',
#  'Bavarian Mountain Scent Hound',
#  'Beagle',
#  'Bearded Collie',
#  'Beauceron',
#  'Bedlington Terrier',
#  'Belgian Laekenois',
#  'Belgian Malinois',
#  'Belgian Sheepdog',
#  'Belgian Tervuren',
#  'Bergamasco Sheepdog',
#  'Berger Picard',
#  'Bernese Mountain Dog',
#  'Bichon Frise',
#  'Biewer Terrier',
#  'Black and Tan Coonhound',
#  'Black Russian Terrier',
#  'Bloodhound',
#  'Bluetick Coonhound',
#  'Boerboel',
#  'Bohemian Shepherd',
#  'Bolognese',
#  'Border Collie',
#  'Border Terrier',
#  'Borzoi',
#  'Boston Terrier',
#  'Bouvier des Flandres',
#  'Boxer',
#  'Boykin Spaniel',
#  'Bracco Italiano',
#  'Braque du Bourbonnais',
#  'Braque Francais Pyrenean',
#  'Briard',
#  'Brittany',
#  'Broholmer',
#  'Brussels Griffon',
#  'Bull Terrier',
#  'Bulldog',
#  'Bullmastiff',
#  'Cairn Terrier',
#  'Canaan Dog',
#  'Cane Corso',
#  'Cardigan Welsh Corgi',
#  'Carolina Dog',
#  'Catahoula Leopard Dog',
#  'Caucasian Shepherd Dog',
#  'Cavalier King Charles Spaniel',
#  'Central Asian Shepherd Dog',
#  'Cesky Terrier',
#  'Chesapeake Bay Retriever',
#  'Chihuahua',
#  'Chinese Crested',
#  'Chinese Shar-Pei',
#  'Chinook',
#  'Chow Chow',
#  'Cirneco dell’Etna',
#  'Clumber Spaniel',
#  'Cocker Spaniel',
#  'Collie',
#  'Coton de Tulear',
#  'Croatian Sheepdog',
#  'Curly-Coated Retriever',
#  'Czechoslovakian Vlcak',
#  'Dachshund',
#  'Dalmatian',
#  'Dandie Dinmont Terrier',
#  'Danish-Swedish Farmdog',
#  'Deutscher Wachtelhund',
#  'Doberman Pinscher',
#  'Dogo Argentino',
#  'Dogue de Bordeaux',
#  'Drentsche Patrijshond',
#  'Drever',
#  'Dutch Shepherd',
#  'English Cocker Spaniel',
#  'English Foxhound',
#  'English Setter',
#  'English Springer Spaniel',
#  'English Toy Spaniel',
#  'Entlebucher Mountain Dog',
#  'Estrela Mountain Dog',
#  'Eurasier',
#  'Field Spaniel',
#  'Finnish Lapphund',
#  'Finnish Spitz',
#  'Flat-Coated Retriever',
#  'French Bulldog',
#  'French Spaniel',
#  'German Longhaired Pointer',
#  'German Pinscher',
#  'German Shepherd Dog',
#  'German Shorthaired Pointer',
#  'German Spitz',
#  'German Wirehaired Pointer',
#  'Giant Schnauzer',
#  'Glen of Imaal Terrier',
#  'Golden Retriever',
#  'Gordon Setter',
#  'Grand Basset Griffon Vendéen',
#  'Great Dane',
#  'Great Pyrenees',
#  'Greater Swiss Mountain Dog',
#  'Greyhound',
#  'Hamiltonstovare',
#  'Hanoverian Scenthound',
#  'Harrier',
#  'Havanese',
#  'Hokkaido',
#  'Hovawart',
#  'Ibizan Hound',
#  'Icelandic Sheepdog',
#  'Irish Red and White Setter',
#  'Irish Setter',
#  'Irish Terrier',
#  'Irish Water Spaniel',
#  'Irish Wolfhound',
#  'Italian Greyhound',
#  'Jagdterrier',
#  'Japanese Chin',
#  'Japanese Spitz',
#  'Jindo',
#  'Kai Ken',
#  'Karelian Bear Dog',
#  'Keeshond',
#  'Kerry Blue Terrier',
#  'Kishu Ken',
#  'Komondor',
#  'Kromfohrlander',
#  'Kuvasz',
#  'Labrador Retriever',
#  'Lagotto Romagnolo',
#  'Lakeland Terrier',
#  'Lancashire Heeler',
#  'Lapponian Herder',
#  'Leonberger',
#  'Lhasa Apso',
#  'Löwchen',
#  'Maltese',
#  'Manchester Terrier (Standard)',
#  'Manchester Terrier (Toy)',
#  'Mastiff',
#  'Miniature American Shepherd',
#  'Miniature Bull Terrier',
#  'Miniature Pinscher',
#  'Miniature Schnauzer',
#  'Mountain Cur',
#  'Mudi',
#  'Neapolitan Mastiff',
#  'Nederlandse Kooikerhondje',
#  'Newfoundland',
#  'Norfolk Terrier',
#  'Norrbottenspets',
#  'Norwegian Buhund',
#  'Norwegian Elkhound',
#  'Norwegian Lundehund',
#  'Norwich Terrier',
#  'Nova Scotia Duck Tolling Retriever',
#  'Old English Sheepdog',
#  'Otterhound',
#  'Papillon',
#  'Parson Russell Terrier',
#  'Pekingese',
#  'Pembroke Welsh Corgi',
#  'Perro de Presa Canario',
#  'Peruvian Inca Orchid',
#  'Petit Basset Griffon Vendéen',
#  'Pharaoh Hound',
#  'Plott Hound',
#  'Pointer',
#  'Polish Lowland Sheepdog',
#  'Pomeranian',
#  'Poodle (Miniature)',
#  'Poodle (Standard)',
#  'Poodle (Toy)',
#  'Porcelaine',
#  'Portuguese Podengo',
#  'Portuguese Podengo Pequeno',
#  'Portuguese Pointer',
#  'Portuguese Sheepdog',
#  'Portuguese Water Dog',
#  'Pudelpointer',
#  'Pug',
#  'Puli',
#  'Pumi',
#  'Pyrenean Mastiff',
#  'Pyrenean Shepherd',
#  'Rafeiro do Alentejo',
#  'Rat Terrier',
#  'Redbone Coonhound',
#  'Rhodesian Ridgeback',
#  'Romanian Mioritic Shepherd Dog',
#  'Rottweiler',
#  'Russell Terrier',
#  'Russian Toy',
#  'Russian Tsvetnaya Bolonka',
#  'Saint Bernard',
#  'Saluki',
#  'Samoyed',
#  'Schapendoes',
#  'Schipperke',
#  'Scottish Deerhound',
#  'Scottish Terrier',
#  'Sealyham Terrier',
#  'Segugio Italiano',
#  'Shetland Sheepdog',
#  'Shiba Inu',
#  'Shih Tzu',
#  'Shikoku',
#  'Siberian Husky',
#  'Silky Terrier',
#  'Skye Terrier',
#  'Sloughi',
#  'Slovakian Wirehaired Pointer',
#  'Slovensky Cuvac',
#  'Slovensky Kopov',
#  'Small Munsterlander Pointer',
#  'Smooth Fox Terrier',
#  'Soft Coated Wheaten Terrier',
#  'Spanish Mastiff',
#  'Spanish Water Dog',
#  'Spinone Italiano',
#  'Stabyhoun',
#  'Staffordshire Bull Terrier',
#  'Standard Schnauzer',
#  'Sussex Spaniel',
#  'Swedish Lapphund',
#  'Swedish Vallhund',
#  'Taiwan Dog',
#  'Teddy Roosevelt Terrier',
#  'Thai Ridgeback',
#  'Tibetan Mastiff',
#  'Tibetan Spaniel',
#  'Tibetan Terrier',
#  'Tornjak',
#  'Tosa',
#  'Toy Fox Terrier',
#  'Transylvanian Hound',
#  'Treeing Tennessee Brindle',
#  'Treeing Walker Coonhound',
#  'Vizsla',
#  'Weimaraner',
#  'Welsh Springer Spaniel',
#  'Welsh Terrier',
#  'West Highland White Terrier',
#  'Wetterhoun',
#  'Whippet',
#  'Wire Fox Terrier',
#  'Wirehaired Pointing Griffon',
#  'Wirehaired Vizsla',
#  'Working Kelpie',
#  'Xoloitzcuintli',
#  'Yakutian Laika',
#  'Yorkshire Terrier']

# %% [markdown]
# ## Menampilkan Kolom Temprament
# kolom temprament memiliki 129 nilai temprament yang unik, karena itu saya membuat kolom temprament_category untuk mengelompokkan temprament menjadi 10 kategori yang lebih umum yaitu: Friendly, Playful, Loyal, Confident, Intelligent, Gentle, Active, Calm, Indepentend, Brave

# %%
temperament_categories = {
    "Amiable": ["Friendly", "Outgoing", "Amiable", "Sociable", "Gregarious"],
    "Playful": ["Playful", "Mischievous", "Fun-Loving", "Lively", "Entertaining", "Energetic"],
    "Loyal": ["Loyal", "Devoted", "Faithful", "Dependable", "Obedient"],
    "Confident": ["Confident", "Self-Confident", "Fearless", "Bold", "Courageous", "Confident Guardian"],
    "Intelligent": ["Very Smart", "Quick", "Intelligent", "Smart", "Observant", "Keenly Observant"],
    "Gentle": ["Gentle", "Sweet-Tempered", "Sweet", "Gentlemanly", "Sweet-Natured"],
    "Active": ["Active", "Spirited", "Keen", "Active", "Vigilant", "Athletic"],
    "Low-Key": ["Calm", "Even-Tempered", "Low-Key"],
    "Independent": ["Independent", "Independent-Minded", "Strong-Willed"],
    "Brave": ["Brave", "Fearless"]
}

# %%
# Function to map temperament to the corresponding category
def map_temperament_category(temperament):
    if isinstance(temperament, float):
        return "Other"  # Handle float values
    for category, traits in temperament_categories.items():
        if any(trait in temperament for trait in traits):
            return category
    return "Other"

# Apply the mapping function to the "temperament" column
dataframe["temperament_category"] = dataframe["temperament"].apply(map_temperament_category)

# %%
dataframe = dataframe.dropna()
dataframe[['temperament', 'temperament_category']]
# Out:
#                                    temperament temperament_category
# 0          Confident, Famously Funny, Fearless            Confident
# 1    Dignified, Profoundly Loyal, Aristocratic                Loyal
# 2                 Friendly, Clever, Courageous              Amiable
# 3      Courageous, Dignified, Profoundly Loyal                Loyal
# 4                 Affectionate, Loyal, Playful              Playful
# ..                                         ...                  ...
# 270               Confident, Alert, Gregarious              Amiable
# 271               Friendly, Devoted, Trainable              Amiable
# 272                   Gentle, Loyal, Trainable                Loyal
# 274                         Loyal, Alert, Calm                Loyal
# 276         Affectionate, Sprightly, Tomboyish                Other
#
# [188 rows x 2 columns]

# %% [markdown]
# ## Menampilkan Data Kolom grooming_frequency_category
# Grooming frequency mengacu pada seberapa sering suatu hewan peliharaan perlu menjalani perawatan dan pemeliharaan rutin terkait kebersihan dan penampilan fisik mereka. Ini melibatkan kegiatan seperti menyisir bulu, mandi, memotong kuku, pembersihan telinga, dan lain sebagainya.

# %%
dataframe['grooming_frequency_category'].unique().tolist()
# dataframe['grooming_frequency_value'].unique().tolist()
# Out:
# ['2-3 Times a Week Brushing',
#  'Daily Brushing',
#  'Occasional Bath/Brush',
#  'Weekly Brushing',
#  'Specialty/Professional']

# %% [markdown]
# ## Menampilkan Data Kolom shedding_category
# Shedding category merujuk pada kategori atau tingkat kehilangan bulu pada hewan peliharaan. Ini menggambarkan seberapa banyak bulu hewan peliharaan rontok secara alami dalam suatu periode waktu tertentu.

# %%
dataframe['shedding_category'].unique().tolist()
# dataframe['shedding_value'].unique().tolist()
# Out:
# ['Seasonal', 'Infrequent', 'Occasional', 'Regularly', 'Frequent']

# %% [markdown]
# ## menampilkan data kolom energy_level_category

# %%
dataframe['energy_level_category'].unique().tolist()
# dataframe['energy_level_value'].unique().tolist()
# Out:
# ['Regular Exercise',
#  'Energetic',
#  'Needs Lots of Activity',
#  'Couch Potato',
#  'Calm']

# %% [markdown]
# ## menampilkan data trainability_category

# %%
dataframe['trainability_category'].unique().tolist()
# Out:
# ['Easy Training',
#  'May be Stubborn',
#  'Eager to Please',
#  'Independent',
#  'Agreeable']

# %% [markdown]
# ## menampilkan data demeanor_category

# %% [markdown]
# Demeanor category merujuk pada kategori atau karakteristik perilaku umum yang dimiliki oleh hewan peliharaan. Ini menggambarkan sifat atau sikap umum yang sering terlihat pada hewan peliharaan.
#
# Demeanor category umumnya digunakan untuk menggambarkan sifat atau sikap umum hewan peliharaan, terutama dalam interaksi dengan manusia dan lingkungan sekitarnya.

# %% [markdown]
# Temperament category mengacu pada sifat atau sikap bawaan yang mendasar yang cenderung konsisten pada hewan peliharaan sepanjang hidup mereka. Ini adalah sifat-sifat yang melekat pada individu dan cenderung dipengaruhi oleh faktor genetik. Contohnya dapat mencakup tingkat keberanian, keaktifan, kecerdasan, kepatuhan, dan kecenderungan terhadap perilaku tertentu. Temperament category dapat memberikan gambaran umum tentang kepribadian hewan peliharaan.
#
# Sementara itu, demeanor category lebih menggambarkan sikap dan perilaku umum yang sering terlihat pada hewan peliharaan dalam interaksi dengan manusia dan lingkungan sekitarnya. Ini dapat mencakup sifat-sifat seperti ramah, bermain, tenang, protektif, dan mandiri. Demeanor category lebih berfokus pada respons dan perilaku hewan peliharaan terhadap lingkungan sekitarnya dan interaksi dengan pemilik atau orang lain.
#
# Perbedaan utama antara temperament category dan demeanor category adalah bahwa temperament category lebih berkaitan dengan sifat bawaan dan karakteristik individu yang cenderung konsisten, sedangkan demeanor category lebih berkaitan dengan sikap dan perilaku umum yang terlihat dalam interaksi sehari-hari. Dalam konteks hewan peliharaan, keduanya dapat memberikan pemahaman yang lebih lengkap tentang sifat dan perilaku hewan peliharaan tersebut.

# %%
dataframe['demeanor_category'].unique().tolist()
# Out:
# ['Outgoing',
#  'Aloof/Wary',
#  'Friendly',
#  'Alert/Responsive',
#  'Reserved with Strangers']

# %% [markdown]
# ## Menampilkan Data Kolom Popularity

# %%
dataframe['popularity'].tolist()
# Out:
# ['148',
#  '113',
#  '60',
#  '47',
#  '58',
#  '175',
#  '122',
#  '186',
#  '85',
#  '166',
#  '90',
#  '55',
#  '17',
#  '140',
#  'of',
#  'of',
#  '87',
#  '39',
#  '6',
#  '127',
#  '124',
#  '43',
#  '125',
#  '106',
#  '187',
#  '144',
#  '22',
#  '46',
#  '138',
#  '118',
#  '49',
#  '130',
#  '121',
#  '35',
#  '88',
#  '103',
#  '21',
#  '84',
#  '11',
#  '100',
#  '132',
#  '26',
#  '98',
#  '62',
#  '5',
#  '51',
#  '69',
#  '179',
#  '32',
#  '68',
#  '18',
#  '185',
#  '45',
#  '33',
#  '79',
#  '64',
#  '190',
#  '75',
#  '183',
#  '143',
#  '30',
#  '38',
#  '81',
#  '162',
#  '12',
#  '56',
#  '176',
#  '17',
#  '67',
#  '52',
#  '188',
#  '94',
#  '27',
#  '135',
#  '157',
#  '149',
#  '161',
#  '184',
#  '91',
#  '4',
#  '134',
#  '2',
#  '9',
#  '63',
#  '174',
#  '3',
#  '115',
#  '177',
#  '16',
#  '66',
#  '74',
#  '145',
#  '189',
#  '24',
#  '152',
#  '155',
#  '77',
#  '159',
#  '76',
#  '73',
#  '104',
#  '95',
#  '173',
#  '163',
#  '1',
#  '99',
#  '147',
#  '93',
#  '71',
#  '168',
#  '37',
#  '133',
#  '133',
#  '29',
#  '34',
#  '110',
#  '70',
#  '19',
#  '102',
#  '150',
#  '40',
#  '126',
#  '165',
#  '97',
#  '191',
#  '108',
#  '83',
#  '72',
#  '182',
#  '54',
#  '117',
#  '92',
#  '13',
#  '156',
#  '172',
#  '171',
#  '114',
#  '170',
#  '23',
#  '7',
#  '7',
#  '154',
#  '50',
#  '28',
#  '160',
#  '151',
#  '181',
#  '86',
#  '142',
#  '41',
#  '8',
#  '82',
#  '48',
#  '120',
#  '59',
#  '105',
#  '158',
#  '57',
#  '164',
#  '25',
#  '44',
#  '20',
#  '14',
#  '112',
#  '178',
#  '192',
#  '123',
#  '53',
#  '153',
#  '80',
#  '89',
#  '180',
#  '169',
#  '131',
#  '119',
#  '96',
#  '111',
#  '137',
#  '31',
#  '36',
#  '107',
#  '42',
#  '61',
#  '101',
#  '65',
#  '167',
#  '140',
#  '10']

# %%
# Mengganti nilai 'of' dengan nilai yang valid
dataframe.loc[dataframe['popularity'] == 'of', 'popularity'] = 50

# %%
invalid_rows = dataframe[dataframe['popularity'] == 'of']
print(invalid_rows)
# Out:
# Empty DataFrame
# Columns: [breed, description, temperament, popularity, min_height, max_height, min_weight, max_weight, min_expectancy, max_expectancy, group, grooming_frequency_value, grooming_frequency_category, shedding_value, shedding_category, energy_level_value, energy_level_category, trainability_value, trainability_category, demeanor_value, demeanor_category, temperament_category]
# Index: []
#
# [0 rows x 22 columns]

# %%
dataframe['popularity'] = dataframe['popularity'].astype(int)

# %% [markdown]
# ## 2. Data Processing

# %% [markdown]
# ## Plotting Function

# %%
def plot(value_counts, title):
    plt.bar(value_counts.index, value_counts.values)
    plt.xlabel('Group')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=45) 
    plt.show()

# %% [markdown]
# ## Membuat Kolom Height, Weight, dan Expectancy

# %%
for col in ['height', 'weight', 'expectancy']:
    dataframe[col] = (dataframe['min_'+col] + dataframe['max_'+col]) / 2

# %%
dataframe[['height', 'min_height', 'max_height']].head()
# Out:
#    height  min_height  max_height
# 0  26.035       22.86       29.21
# 1  66.040       63.50       68.58
# 2  58.420       58.42       58.42
# 3  66.040       60.96       71.12
# 4  60.960       58.42       63.50

# %%
dataframe.head()
# Out:
#               breed                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament  popularity  min_height  \
# 0        Confident, Famously Funny, Fearless         148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic         113       63.50
# 2               Friendly, Clever, Courageous          60       58.42
# 3    Courageous, Dignified, Profoundly Loyal          47       60.96
# 4               Affectionate, Loyal, Playful          58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   energy_level_value  energy_level_category trainability_value  \
# 0                0.6       Regular Exercise                0.8
# 1                0.8              Energetic                0.2
# 2                0.6       Regular Exercise                1.0
# 3                0.8              Energetic                1.0
# 4                0.8              Energetic                0.4
#
#    trainability_category demeanor_value  demeanor_category  \
# 0          Easy Training            1.0           Outgoing
# 1        May be Stubborn            0.2         Aloof/Wary
# 2        Eager to Please            0.8           Friendly
# 3        Eager to Please            0.6   Alert/Responsive
# 4            Independent            0.8           Friendly
#
#   temperament_category  height     weight  expectancy
# 0            Confident  26.035   3.855535        13.5
# 1                Loyal  66.040  24.947580        13.5
# 2              Amiable  58.420  27.215542        12.5
# 3                Loyal  66.040  45.359237        11.5
# 4              Playful  60.960  36.287390        12.0
#
# [5 rows x 25 columns]

# %%
dataframe['group'].unique().tolist()
# Out:
# ['Toy Group',
#  'Hound Group',
#  'Terrier Group',
#  'Working Group',
#  'Non-Sporting Group',
#  'Sporting Group',
#  'Herding Group']

# %%
dataframe['group'].value_counts()
# Out:
# Hound Group           32
# Herding Group         30
# Sporting Group        29
# Working Group         29
# Terrier Group         27
# Toy Group             21
# Non-Sporting Group    20
# Name: group, dtype: int64

# %%
group_counts = dataframe['group'].value_counts()

plot(group_counts, 'Dog Group Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Height Menjadi 4 Kategori

# %%
dataframe['height_category'] = pd.cut(dataframe['height'],
                                      bins=[0, 30, 50, 70, float('inf')],
                                      labels=['Short', 'Medium', 'Tall', 'Very Tall'])
dataframe['height_category'].unique().tolist()
## display group with height category
dataframe[['group', 'height_category']].head(20)
# Out:
#                  group height_category
# 0            Toy Group           Short
# 1          Hound Group            Tall
# 2        Terrier Group            Tall
# 3        Working Group            Tall
# 4        Working Group            Tall
# 6          Hound Group            Tall
# 7   Non-Sporting Group          Medium
# 8          Hound Group            Tall
# 11       Terrier Group          Medium
# 12      Sporting Group          Medium
# 13       Working Group       Very Tall
# 15       Herding Group          Medium
# 17       Herding Group            Tall
# 19       Terrier Group           Short
# 20         Hound Group            Tall
# 21      Sporting Group            Tall
# 22         Hound Group          Medium
# 24         Hound Group          Medium
# 26         Hound Group          Medium
# 27       Herding Group            Tall

# %%
height_counts = dataframe['height_category'].value_counts()

plot(height_counts, 'Dog Height Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Weight Menjadi 4 Kategori

# %%
dataframe['weight_category'] = pd.cut(dataframe['weight'],
                                      bins=[0, 10, 30, 50, float('inf')],
                                      labels=['Light', 'Medium', 'Heavy', 'Very Heavy'])
default_weight_category = 'Medium'
dataframe['weight_category'] = dataframe['weight_category'].fillna(default_weight_category)

# %%
# count weight category
weights_counts = dataframe['weight_category'].value_counts()

plot(weights_counts, 'Dog Weight Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Expectancy Menjadi 4 Kategori

# %%
# Categorize expectancy
dataframe['expectancy_category'] = pd.cut(dataframe['max_expectancy'],
                                          bins=[0, 5, 10, 15, float('inf')],
                                          labels=['Short', 'Medium', 'Long', 'Very Long'])
dataframe['expectancy_category'] = dataframe['expectancy_category'].fillna('Short')
dataframe['expectancy_category'].unique().tolist()
dataframe['expectancy_category'].value_counts()
# Out:
# Long         146
# Very Long     26
# Medium        15
# Short          1
# Name: expectancy_category, dtype: int64

# %%
dataframe.dtypes
# Out:
# breed                            object
# description                      object
# temperament                      object
# popularity                        int32
# min_height                      float64
# max_height                      float64
# min_weight                      float64
# max_weight                      float64
# min_expectancy                  float64
# max_expectancy                  float64
# group                            object
# grooming_frequency_value        float64
# grooming_frequency_category      object
# shedding_value                  float64
# shedding_category                object
# energy_level_value              float64
# energy_level_category            object
# trainability_value              float64
# trainability_category            object
# demeanor_value                  float64
# demeanor_category                object
# temperament_category             object
# height                          float64
# weight                          float64
# expectancy                      float64
# height_category                category
# weight_category                category
# expectancy_category            category
# dtype: object

# %%
num_classes = len(dataframe['group'].unique())
print('Number of classes: {}'.format(num_classes))
# Out:
# Number of classes: 7

# %%
dataframe.isnull().sum()
# Out:
# breed                          0
# description                    0
# temperament                    0
# popularity                     0
# min_height                     0
# max_height                     0
# min_weight                     0
# max_weight                     0
# min_expectancy                 0
# max_expectancy                 0
# group                          0
# grooming_frequency_value       0
# grooming_frequency_category    0
# shedding_value                 0
# shedding_category              0
# energy_level_value             0
# energy_level_category          0
# trainability_value             0
# trainability_category          0
# demeanor_value                 0
# demeanor_category              0
# temperament_category           0
# height                         0
# weight                         0
# expectancy                     0
# height_category                0
# weight_category                0
# expectancy_category            0
# dtype: int64

# %% [markdown]
# ## Analisis Korelasi Menggunakan Chi Square dan P-Value

# %%
from scipy.stats import chi2_contingency

# Select the features and target variable
features = [
    'trainability_category', 
    'energy_level_category', 
    'shedding_category', 
    'grooming_frequency_category', 
    'temperament_category', 
    'weight_category',
    'height_category',
    'demeanor_category',
]
target = 'group'

# Create contingency tables for each feature and the target variable
contingency_tables = []
for feature in features:
    contingency_table = pd.crosstab(dataframe[feature], dataframe[target])
    contingency_tables.append(contingency_table)

# Perform chi-square test for each contingency table
results = []
for contingency_table in contingency_tables:
    chi2, p, _, _ = chi2_contingency(contingency_table)
    results.append((chi2, p))

# Print the results
for i, feature in enumerate(features):
    chi2, p = results[i]
    print(f"Correlation between {feature} and 'group':")
    print(f"Chi-square statistic: {chi2}")
    print(f"P-value: {p}")
    print()
# Out:
# Correlation between trainability_category and 'group':
# Chi-square statistic: 58.71361983511409
# P-value: 9.681745790331512e-05
#
# Correlation between energy_level_category and 'group':
# Chi-square statistic: 55.742976287121465
# P-value: 0.000248367971162948
#
# Correlation between shedding_category and 'group':
# Chi-square statistic: 61.764720876725
# P-value: 3.584257973798279e-05
#
# Correlation between grooming_frequency_category and 'group':
# Chi-square statistic: 30.99580203792884
# P-value: 0.15390376047888413
#
# Correlation between temperament_category and 'group':
# Chi-square statistic: 80.3787008921028
# P-value: 0.011441448748237118
#
# Correlation between weight_category and 'group':
# Chi-square statistic: 179.8882141026399
# P-value: 1.0092133561892333e-28
#
# Correlation between height_category and 'group':
# Chi-square statistic: 156.72941977732924
# P-value: 3.632187307424734e-24
#
# Correlation between demeanor_category and 'group':
# Chi-square statistic: 39.81082321148291
# P-value: 0.022408654803944775

# %% [markdown]
# ## 3. Training

# %%
## callbacks
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.95):
            print("\nReached 95% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

# %%
# Convert categorical columns to category type
categorical_cols = [
                    'trainability_category', 
                    'energy_level_category', 
                    'shedding_category',
                    'grooming_frequency_category', 
                    'temperament_category', 
                    'weight_category',
                    'height_category',
                    'demeanor_category'
                    ]

dataframe[categorical_cols] = dataframe[categorical_cols].astype('category')



# Select the features and target variable
features = [
            'trainability_category', 
            'energy_level_category', 
            'shedding_category', 
            'grooming_frequency_category', 
            'temperament_category', 
            'weight_category',
            'height_category',
            'demeanor_category',
            ]


target = 'group'
X = dataframe[features]
y = dataframe[target]

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Create feature columns for categorical features
feature_columns = []
for col in categorical_cols:
    vocab = X[col].cat.categories.tolist()
    cat_column = tf.feature_column.categorical_column_with_vocabulary_list(col, vocab)
    emb_column = tf.feature_column.embedding_column(cat_column, dimension=8)
    feature_columns.append(emb_column)

# Create input functions for training and evaluation
def input_fn(features, labels, batch_size=32, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(features))
    dataset = dataset.batch(batch_size)
    return dataset

# Create the model
# model = tf.keras.Sequential([
#     tf.keras.layers.DenseFeatures(feature_columns),
#     tf.keras.layers.Dense(512, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(32, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(16, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(num_classes, activation='softmax')
# ])

model = tf.keras.Sequential([
    tf.keras.layers.DenseFeatures(feature_columns),
    tf.keras.layers.Dense(16, kernel_regularizer=regularizers.l2(0.001), activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax'),

])

# model.summary()


# Compile the model
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
batch_size = 32
train_dataset = input_fn(X_train, y_train, batch_size=batch_size)
validation_dataset = input_fn(X_test, y_test, batch_size=batch_size, shuffle=False)
history = model.fit(train_dataset, validation_data=validation_dataset, epochs=100, callbacks=[callbacks])
# Out:
# Train for 5 steps, validate for 2 steps
# Epoch 1/100
# 5/5 [==============================] - 17s 3s/step - loss: 1.8711 - accuracy: 0.2467 - val_loss: 1.7126 - val_accuracy: 0.2632
# Epoch 2/100
# 5/5 [==============================] - 0s 80ms/step - loss: 1.5801 - accuracy: 0.4400 - val_loss: 1.6232 - val_accuracy: 0.2632
# Epoch 3/100
# 5/5 [==============================] - 0s 93ms/step - loss: 1.3926 - accuracy: 0.4933 - val_loss: 1.5395 - val_accuracy: 0.3684
# Epoch 4/100
# 5/5 [==============================] - 0s 93ms/step - loss: 1.2338 - accuracy: 0.5600 - val_loss: 1.5545 - val_accuracy: 0.4211
# Epoch 5/100
# 5/5 [==============================] - 0s 92ms/step - loss: 1.1765 - accuracy: 0.6200 - val_loss: 1.5442 - val_accuracy: 0.4211
# Epoch 6/100
# 5/5 [==============================] - 0s 89ms/step - loss: 1.0657 - accuracy: 0.6133 - val_loss: 1.5501 - val_accuracy: 0.3947
# Epoch 7/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.9753 - accuracy: 0.6800 - val_loss: 1.5001 - val_accuracy: 0.4211
# Epoch 8/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.9144 - accuracy: 0.6867 - val_loss: 1.5899 - val_accuracy: 0.3684
# Epoch 9/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.8601 - accuracy: 0.7133 - val_loss: 1.6014 - val_accuracy: 0.3421
# Epoch 10/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.8404 - accuracy: 0.7533 - val_loss: 1.6028 - val_accuracy: 0.3947
# Epoch 11/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.8278 - accuracy: 0.7133 - val_loss: 1.6183 - val_accuracy: 0.3421
# Epoch 12/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.7345 - accuracy: 0.8000 - val_loss: 1.7216 - val_accuracy: 0.3947
# Epoch 13/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7115 - accuracy: 0.7533 - val_loss: 1.6762 - val_accuracy: 0.3421
# Epoch 14/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6723 - accuracy: 0.7867 - val_loss: 1.7124 - val_accuracy: 0.4474
# Epoch 15/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.6576 - accuracy: 0.7867 - val_loss: 1.8394 - val_accuracy: 0.4474
# Epoch 16/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6104 - accuracy: 0.8067 - val_loss: 1.8643 - val_accuracy: 0.4211
# Epoch 17/100
# 5/5 [==============================] - 1s 128ms/step - loss: 0.5753 - accuracy: 0.8333 - val_loss: 1.8716 - val_accuracy: 0.4474
# Epoch 18/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.5450 - accuracy: 0.8467 - val_loss: 1.9757 - val_accuracy: 0.4474
# Epoch 19/100
# 5/5 [==============================] - 1s 130ms/step - loss: 0.5318 - accuracy: 0.8533 - val_loss: 1.9831 - val_accuracy: 0.3947
# Epoch 20/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.4883 - accuracy: 0.8800 - val_loss: 2.1586 - val_accuracy: 0.3947
# Epoch 21/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.4792 - accuracy: 0.8667 - val_loss: 2.1150 - val_accuracy: 0.4211
# Epoch 22/100
# 5/5 [==============================] - 1s 117ms/step - loss: 0.4422 - accuracy: 0.9067 - val_loss: 2.2302 - val_accuracy: 0.4474
# Epoch 23/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4082 - accuracy: 0.9067 - val_loss: 2.2592 - val_accuracy: 0.3684
# Epoch 24/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.4072 - accuracy: 0.9267 - val_loss: 2.3213 - val_accuracy: 0.4211
# Epoch 25/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.3853 - accuracy: 0.9133 - val_loss: 2.3142 - val_accuracy: 0.3947
# Epoch 26/100
# 5/5 [==============================] - 1s 124ms/step - loss: 0.3766 - accuracy: 0.9333 - val_loss: 2.3817 - val_accuracy: 0.4211
# Epoch 27/100
# 4/5 [=======================>......] - ETA: 0s - loss: 0.3280 - accuracy: 0.9609
# Reached 95% accuracy so cancelling training!
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3412 - accuracy: 0.9533 - val_loss: 2.3976 - val_accuracy: 0.4211

# %%
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_features_20 (DenseFeat multiple                  344
# _________________________________________________________________
# dense_117 (Dense)            multiple                  1040
# _________________________________________________________________
# dense_118 (Dense)            multiple                  119
# =================================================================
# Total params: 1,503
# Trainable params: 1,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Evaluasi model
test_dataset = input_fn(X_test, y_test, batch_size=batch_size, shuffle=False)
_, accuracy = model.evaluate(test_dataset)
print("Akurasi: ", accuracy)
# Out:
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3976 - accuracy: 0.4211
# Akurasi:  0.42105263

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

# Mendapatkan prediksi dari model untuk data validasi
y_pred = model.predict(test_dataset)
y_pred = np.argmax(y_pred, axis=1)  # Mengambil indeks kelas dengan probabilitas tertinggi sebagai prediksi

# Mengonversi label kelas validasi ke dalam bentuk numerik
label_encoder = LabelEncoder()
y_true_numeric = label_encoder.fit_transform(y_test)

# Menghitung metrik presisi
precision = precision_score(y_true_numeric, y_pred, average='weighted')

# Menghitung metrik recall
recall = recall_score(y_true_numeric, y_pred, average='weighted')

# Menghitung metrik F1-score
f1 = f1_score(y_true_numeric, y_pred, average='weighted')

print("Presisi:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Presisi: 0.48407477025898077
# Recall: 0.42105263157894735
# F1-score: 0.4251797007601961

# %% [markdown]
# menunjukkan bahwa model memiliki tingkat presisi dan recall yang cukup rendah.

# %%
# Get training and validation accuracy values
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot training and validation accuracy
epochs = range(1, len(train_acc) + 1)
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Get training and validation accuracy values
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
epochs = range(1, len(train_acc) + 1)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Create a new dataframe with input features for prediction

new_data = pd.DataFrame({
    "trainability_category": ["Eager to Please"],
  "energy_level_category": ["Needs Lots of Activity"],
  "shedding_category": ["Frequent"],
  "grooming_frequency_category": ["Weekly Brushing"],
  "temperament_category": ["Loyal"],
  "weight_category": ["Heavy"],
  "height_category": ["Tall"],
  "demeanor_category": ["Friendly"]
})


# Convert the new data to individual arrays for prediction
new_data_arrays = [new_data[feature].values.reshape(-1, 1) for feature in [
    'trainability_category', 
    'energy_level_category', 
    'shedding_category', 
    'grooming_frequency_category', 
    'temperament_category', 
    'weight_category',
    'height_category',
    'demeanor_category',
    ]
    ]

# Make predictions on the new data
predictions = model.predict(new_data_arrays)

# Decode the predicted breed labels
predicted_labels = np.argmax(predictions, axis=1)
predicted_labels = label_encoder.inverse_transform(predicted_labels)

# Menampilkan hasil prediksi
for label in predicted_labels:
    print(label)
    breeds = dataframe.loc[dataframe['group'] == label]
     # Sort by popularity in descending order
    breeds = breeds.sort_values('popularity', ascending=False)
    # Get top 5 breeds
    top_breeds = breeds.head(5)
    # print(top_breeds)
    # print('\n')

pd.DataFrame(breeds)
# Out:
# Sporting Group
#                                   breed  \
# 248                      Sussex Spaniel
# 272                   Wirehaired Vizsla
# 12               American Water Spaniel
# 85               Curly-Coated Retriever
# 138                 Irish Water Spaniel
# 172           Nederlandse Kooikerhondje
# 106                       Field Spaniel
# 80                      Clumber Spaniel
# 121                       Gordon Setter
# 192                             Pointer
# 52                       Boykin Spaniel
# 154                   Lagotto Romagnolo
# 100                      English Setter
# 109               Flat-Coated Retriever
# 180  Nova Scotia Duck Tolling Retriever
# 136                        Irish Setter
# 271         Wirehaired Pointing Griffon
# 117           German Wirehaired Pointer
# 98               English Cocker Spaniel
# 21                               Barbet
# 73             Chesapeake Bay Retriever
# 264                          Weimaraner
# 263                              Vizsla
# 81                       Cocker Spaniel
# 101            English Springer Spaniel
# 57                             Brittany
# 115          German Shorthaired Pointer
# 120                    Golden Retriever
# 153                  Labrador Retriever
#
#                                            description  \
# 248  Sussex are long, low-built bird dogs of great ...
# 272  WVs are close relatives of Vizslas but a disti...
# 12   American Water Spaniels are muscular midsize g...
# 85   The Curly-Coated Retriever’s tight, crisp curl...
# 138  Standing 21 to 24 inches at the shoulder and w...
# 172  The Kooikerhondje (Koi-ker-hond-yuh)—the “litt...
# 106  Field Spaniels bear a family resemblance to Co...
# 80   Clumber Spaniels are powerful bird dogs of hea...
# 121  Gordons are the largest and most substantial o...
# 192  The noble Pointer is the ultimate expression o...
# 52   Boykins are medium-sized spaniels, larger and ...
# 154  Italians have a word for it: “carino.” In Engl...
# 100  English Setters are elegant but solid dogs of ...
# 109  The Flat-Coated Retriever’s eponymous flat-lyi...
# 180  The little gundog with the big name is the sma...
# 136  The Irish Setter has been described by its par...
# 271  Griffs are medium-sized, all-purpose gundogs s...
# 117  Standing as high as 26 inches at the shoulder,...
# 98   The English Cocker Spaniel is a compactly buil...
# 21   The defining characteristic of this rustic, me...
# 73   Chessies are strong, powerfully built gundogs ...
# 264  Instantly recognized by a distinctive silvery-...
# 263  The Vizsla is easily recognized by his sleek g...
# 81   Those big, dark eyes; that sweet expression; t...
# 101  Built for long days in the field, English Spri...
# 57   Brittanys are smaller than setters but leggier...
# 115  Male German Shorthaired Pointers stand between...
# 120  The Golden Retriever is a sturdy, muscular dog...
# 153  The sturdy, well-balanced Labrador Retriever c...
#
#                              temperament  popularity  min_height  max_height  \
# 248       Friendly, Merry, Even-Tempered         180       33.02       38.10
# 272             Gentle, Loyal, Trainable         167       54.61       63.50
# 12                Eager, Happy, Charming         166       38.10       45.72
# 85      Confident, Proud, Wickedly Smart         162       58.42       68.58
# 138          Playful, Hardworking, Brave         159       53.34       60.96
# 172               Friendly, Alert, Quick         150       35.56       43.18
# 106         Sweet, Fun-Loving, Sensitive         149       43.18       45.72
# 80          Mellow, Amusing, Gentlemanly         143       43.18       50.80
# 121        Affectionate, Confident, Bold         115       58.42       68.58
# 192    Loyal, Hardworking, Even-Tempered         114       58.42       71.12
# 52              Friendly, Eager, Lovable         100       35.56       45.72
# 154      Affectionate, Keen, Undemanding          99       40.64       48.26
# 100              Friendly, Mellow, Merry          94       58.42       68.58
# 109   Cheerful, Optimistic, Good-Humored          91       55.88       62.23
# 180  Affectionate, Intelligent, Outgoing          83       43.18       53.34
# 136      Active, Outgoing, Sweet-Natured          77       63.50       68.58
# 271         Friendly, Devoted, Trainable          65       50.80       60.96
# 117    Affectionate, Eager, Enthusiastic          63       55.88       66.04
# 98          Energetic, Merry, Responsive          52       38.10       43.18
# 21       Friendly, Bright, Sweet-Natured          50       48.26       62.23
# 73       Affectionate, Bright, Sensitive          45       53.34       66.04
# 264         Friendly, Fearless, Obedient          36       58.42       68.58
# 263      Affectionate, Gentle, Energetic          31       53.34       60.96
# 81                  Gentle, Smart, Happy          30       34.29       39.37
# 101          Friendly, Playful, Obedient          27       48.26       50.80
# 57            Bright, Fun-Loving, Upbeat          26       44.45       52.07
# 115   Friendly, Smart, Willing to Please           9       53.34       63.50
# 120       Friendly, Intelligent, Devoted           3       54.61       60.96
# 153           Friendly, Active, Outgoing           1       54.61       62.23
#
#      min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 248   15.875733   20.411657            13.0            15.0  ...
# 272   20.411657   29.483504            12.0            14.0  ...
# 12    11.339809   20.411657            10.0            14.0  ...
# 85    27.215542   43.091275            10.0            12.0  ...
# 138   20.411657   30.844281            12.0            13.0  ...
# 172    9.071847   13.607771            12.0            15.0  ...
# 106   15.875733   22.679619            12.0            13.0  ...
# 80    24.947580   38.555351            10.0            12.0  ...
# 121   20.411657   36.287390            12.0            13.0  ...
# 192   20.411657   34.019428            12.0            17.0  ...
# 52    11.339809   18.143695            10.0            15.0  ...
# 154   10.886217   15.875733            15.0            17.0  ...
# 100   20.411657   36.287390            12.0            12.0  ...
# 109   27.215542   31.751466             8.0            10.0  ...
# 180   15.875733   22.679619            12.0            14.0  ...
# 136   27.215542   31.751466            12.0            15.0  ...
# 271   15.875733   31.751466            12.0            15.0  ...
# 117   22.679619   31.751466            14.0            16.0  ...
# 98    11.793402   15.422141            12.0            14.0  ...
# 21    15.875733   29.483504            12.0            14.0  ...
# 73    24.947580   36.287390            10.0            13.0  ...
# 264   24.947580   40.823313            10.0            13.0  ...
# 263   19.958064   27.215542            12.0            14.0  ...
# 81     9.071847   13.607771            10.0            14.0  ...
# 101   18.143695   22.679619            12.0            14.0  ...
# 57    13.607771   18.143695            12.0            14.0  ...
# 115   20.411657   31.751466            10.0            12.0  ...
# 120   24.947580   34.019428            10.0            12.0  ...
# 153   24.947580   36.287390            10.0            12.0  ...
#
#     trainability_category  demeanor_value        demeanor_category  \
# 248           Independent             0.4  Reserved with Strangers
# 272             Agreeable             0.6         Alert/Responsive
# 12        Eager to Please             0.8                 Friendly
# 85            Independent             0.4  Reserved with Strangers
# 138         Easy Training             0.4  Reserved with Strangers
# 172       Eager to Please             0.4  Reserved with Strangers
# 106             Agreeable             0.4  Reserved with Strangers
# 80              Agreeable             0.4  Reserved with Strangers
# 121           Independent             0.4  Reserved with Strangers
# 192             Agreeable             0.6         Alert/Responsive
# 52        Eager to Please             0.6         Alert/Responsive
# 154       Eager to Please             0.6         Alert/Responsive
# 100         Easy Training             0.8                 Friendly
# 109       Eager to Please             0.8                 Friendly
# 180         Easy Training             0.8                 Friendly
# 136             Agreeable             1.0                 Outgoing
# 271             Agreeable             0.6         Alert/Responsive
# 117       Eager to Please             0.4  Reserved with Strangers
# 98        Eager to Please             0.8                 Friendly
# 21              Agreeable             0.8                 Friendly
# 73              Agreeable             0.4  Reserved with Strangers
# 264       Eager to Please             0.8                 Friendly
# 263       Eager to Please             0.8                 Friendly
# 81        Eager to Please             1.0                 Outgoing
# 101       Eager to Please             0.8                 Friendly
# 57        Eager to Please             0.8                 Friendly
# 115       Eager to Please             0.8                 Friendly
# 120       Eager to Please             0.8                 Friendly
# 153       Eager to Please             1.0                 Outgoing
#
#      temperament_category  height     weight expectancy  height_category  \
# 248               Amiable  35.560  18.143695       14.0           Medium
# 272                 Loyal  59.055  24.947580       13.0             Tall
# 12                  Other  41.910  15.875733       12.0           Medium
# 85              Confident  63.500  35.153409       11.0             Tall
# 138               Playful  57.150  25.627969       12.5             Tall
# 172               Amiable  39.370  11.339809       13.5           Medium
# 106               Playful  44.450  19.277676       12.5           Medium
# 80                 Gentle  46.990  31.751466       11.0           Medium
# 121             Confident  63.500  28.349523       12.5             Tall
# 192                 Loyal  64.770  27.215542       14.5             Tall
# 52                Amiable  40.640  14.741752       12.5           Medium
# 154                Active  44.450  13.380975       16.0           Medium
# 100               Amiable  63.500  28.349523       12.0             Tall
# 109                 Other  59.055  29.483504        9.0             Tall
# 180               Amiable  48.260  19.277676       13.0           Medium
# 136               Amiable  66.040  29.483504       13.5             Tall
# 271               Amiable  55.880  23.813599       13.5             Tall
# 117                 Other  60.960  27.215542       15.0             Tall
# 98                Playful  40.640  13.607771       13.0           Medium
# 21                Amiable  55.245  22.679619       13.0             Tall
# 73                  Other  59.690  30.617485       11.5             Tall
# 264               Amiable  63.500  32.885447       11.5             Tall
# 263               Playful  57.150  23.586803       13.0             Tall
# 81            Intelligent  36.830  11.339809       12.0           Medium
# 101               Amiable  49.530  20.411657       13.0           Medium
# 57                Playful  48.260  15.875733       13.0           Medium
# 115               Amiable  58.420  26.081561       11.0             Tall
# 120               Amiable  57.785  29.483504       11.0             Tall
# 153               Amiable  58.420  30.617485       11.0             Tall
#
#     weight_category  expectancy_category
# 248          Medium                 Long
# 272          Medium                 Long
# 12           Medium                 Long
# 85            Heavy                 Long
# 138          Medium                 Long
# 172          Medium                 Long
# 106          Medium                 Long
# 80            Heavy                 Long
# 121          Medium                 Long
# 192          Medium            Very Long
# 52           Medium                 Long
# 154          Medium            Very Long
# 100          Medium                 Long
# 109          Medium               Medium
# 180          Medium                 Long
# 136          Medium                 Long
# 271          Medium                 Long
# 117          Medium            Very Long
# 98           Medium                 Long
# 21           Medium                 Long
# 73            Heavy                 Long
# 264           Heavy                 Long
# 263          Medium                 Long
# 81           Medium                 Long
# 101          Medium                 Long
# 57           Medium                 Long
# 115          Medium                 Long
# 120          Medium                 Long
# 153           Heavy                 Long
#
# [29 rows x 28 columns]

# %%
# new_data.to_json('new_data.json', orient='records', lines=False)

# %%
print(new_data_arrays)
# Out:
# [array([['Eager to Please']], dtype=object), array([['Needs Lots of Activity']], dtype=object), array([['Frequent']], dtype=object), array([['Weekly Brushing']], dtype=object), array([['Loyal']], dtype=object), array([['Heavy']], dtype=object), array([['Tall']], dtype=object), array([['Friendly']], dtype=object)]

# %% [markdown]
# ## Save the Model

# %%
tf.saved_model.save(model, './model')
# Out:
# INFO:tensorflow:Assets written to: ./model\assets

# %%
# Save the model
model.save('./model/model.h5')

# %%
# Save the LabelEncoder
np.save('./model/label_encoder.npy', label_encoder.classes_)
