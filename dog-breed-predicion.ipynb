# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Embedding, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## 1.  Data Collection

# %%
dataframe = pd.read_csv('./data/akc-data-latest-v1.csv')
dataframe.head()
# Out:
#               breed                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
dataframe.columns.tolist()
# Out:
# ['breed',
#  'description',
#  'temperament',
#  'popularity',
#  'min_height',
#  'max_height',
#  'min_weight',
#  'max_weight',
#  'min_expectancy',
#  'max_expectancy',
#  'group',
#  'grooming_frequency_value',
#  'grooming_frequency_category',
#  'shedding_value',
#  'shedding_category',
#  'energy_level_value',
#  'energy_level_category',
#  'trainability_value',
#  'trainability_category',
#  'demeanor_value',
#  'demeanor_category']

# %% [markdown]
# Kolom "min_expectancy" dan "max_expectancy" mengacu pada harapan hidup minimum dan maksimum dari ras anjing, dengan tahun sebagai unit pengukuran.
#
# Kolom "group" mengacu pada 7 kelompok anjing utama, tetapi ada 2 nilai yang salah untuk "Foundation Stock Service" dan "Miscellaneous Class".

# %%
dataframe['group'].unique().tolist()
# Out:
# ['Toy Group',
#  'Hound Group',
#  'Terrier Group',
#  'Working Group',
#  'Foundation Stock Service',
#  'Non-Sporting Group',
#  'Sporting Group',
#  'Herding Group',
#  'Miscellaneous Class']

# %% [markdown]
# Kolom dengan "_value" pada namanya memiliki nilai 0.2, 0.4, 0.6, 0.8, atau 1. yang sesuai dengan nilai kolom dengan "_category" pada namanya. Angka yang lebih tinggi menunjukkan bahwa ras tersebut memiliki lebih banyak sifat yang dirujuk oleh kolom tersebut. Misalnya, untuk shedding_value, angka yang lebih tinggi berarti breed tersebut lebih sering rontok, yang ditunjukkan oleh shedding_category.

# %%
dataframe[['shedding_value', 'shedding_category']].head()
# Out:
#    shedding_value shedding_category
# 0             0.6          Seasonal
# 1             0.2        Infrequent
# 2             0.4        Occasional
# 3             0.6          Seasonal
# 4             0.6          Seasonal

# %% [markdown]
# ## Menampilkan Kolom Breed

# %%
dataframe['breed'].tolist()
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American English Coonhound',
#  'American Eskimo Dog',
#  'American Foxhound',
#  'American Hairless Terrier',
#  'American Leopard Hound',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Anatolian Shepherd Dog',
#  'Appenzeller Sennenhund',
#  'Australian Cattle Dog',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Stumpy Tail Cattle Dog',
#  'Australian Terrier',
#  'Azawakh',
#  'Barbet',
#  'Basenji',
#  'Basset Fauve de Bretagne',
#  'Basset Hound',
#  'Bavarian Mountain Scent Hound',
#  'Beagle',
#  'Bearded Collie',
#  'Beauceron',
#  'Bedlington Terrier',
#  'Belgian Laekenois',
#  'Belgian Malinois',
#  'Belgian Sheepdog',
#  'Belgian Tervuren',
#  'Bergamasco Sheepdog',
#  'Berger Picard',
#  'Bernese Mountain Dog',
#  'Bichon Frise',
#  'Biewer Terrier',
#  'Black and Tan Coonhound',
#  'Black Russian Terrier',
#  'Bloodhound',
#  'Bluetick Coonhound',
#  'Boerboel',
#  'Bohemian Shepherd',
#  'Bolognese',
#  'Border Collie',
#  'Border Terrier',
#  'Borzoi',
#  'Boston Terrier',
#  'Bouvier des Flandres',
#  'Boxer',
#  'Boykin Spaniel',
#  'Bracco Italiano',
#  'Braque du Bourbonnais',
#  'Braque Francais Pyrenean',
#  'Briard',
#  'Brittany',
#  'Broholmer',
#  'Brussels Griffon',
#  'Bull Terrier',
#  'Bulldog',
#  'Bullmastiff',
#  'Cairn Terrier',
#  'Canaan Dog',
#  'Cane Corso',
#  'Cardigan Welsh Corgi',
#  'Carolina Dog',
#  'Catahoula Leopard Dog',
#  'Caucasian Shepherd Dog',
#  'Cavalier King Charles Spaniel',
#  'Central Asian Shepherd Dog',
#  'Cesky Terrier',
#  'Chesapeake Bay Retriever',
#  'Chihuahua',
#  'Chinese Crested',
#  'Chinese Shar-Pei',
#  'Chinook',
#  'Chow Chow',
#  'Cirneco dell’Etna',
#  'Clumber Spaniel',
#  'Cocker Spaniel',
#  'Collie',
#  'Coton de Tulear',
#  'Croatian Sheepdog',
#  'Curly-Coated Retriever',
#  'Czechoslovakian Vlcak',
#  'Dachshund',
#  'Dalmatian',
#  'Dandie Dinmont Terrier',
#  'Danish-Swedish Farmdog',
#  'Deutscher Wachtelhund',
#  'Doberman Pinscher',
#  'Dogo Argentino',
#  'Dogue de Bordeaux',
#  'Drentsche Patrijshond',
#  'Drever',
#  'Dutch Shepherd',
#  'English Cocker Spaniel',
#  'English Foxhound',
#  'English Setter',
#  'English Springer Spaniel',
#  'English Toy Spaniel',
#  'Entlebucher Mountain Dog',
#  'Estrela Mountain Dog',
#  'Eurasier',
#  'Field Spaniel',
#  'Finnish Lapphund',
#  'Finnish Spitz',
#  'Flat-Coated Retriever',
#  'French Bulldog',
#  'French Spaniel',
#  'German Longhaired Pointer',
#  'German Pinscher',
#  'German Shepherd Dog',
#  'German Shorthaired Pointer',
#  'German Spitz',
#  'German Wirehaired Pointer',
#  'Giant Schnauzer',
#  'Glen of Imaal Terrier',
#  'Golden Retriever',
#  'Gordon Setter',
#  'Grand Basset Griffon Vendéen',
#  'Great Dane',
#  'Great Pyrenees',
#  'Greater Swiss Mountain Dog',
#  'Greyhound',
#  'Hamiltonstovare',
#  'Hanoverian Scenthound',
#  'Harrier',
#  'Havanese',
#  'Hokkaido',
#  'Hovawart',
#  'Ibizan Hound',
#  'Icelandic Sheepdog',
#  'Irish Red and White Setter',
#  'Irish Setter',
#  'Irish Terrier',
#  'Irish Water Spaniel',
#  'Irish Wolfhound',
#  'Italian Greyhound',
#  'Jagdterrier',
#  'Japanese Chin',
#  'Japanese Spitz',
#  'Jindo',
#  'Kai Ken',
#  'Karelian Bear Dog',
#  'Keeshond',
#  'Kerry Blue Terrier',
#  'Kishu Ken',
#  'Komondor',
#  'Kromfohrlander',
#  'Kuvasz',
#  'Labrador Retriever',
#  'Lagotto Romagnolo',
#  'Lakeland Terrier',
#  'Lancashire Heeler',
#  'Lapponian Herder',
#  'Leonberger',
#  'Lhasa Apso',
#  'Löwchen',
#  'Maltese',
#  'Manchester Terrier (Standard)',
#  'Manchester Terrier (Toy)',
#  'Mastiff',
#  'Miniature American Shepherd',
#  'Miniature Bull Terrier',
#  'Miniature Pinscher',
#  'Miniature Schnauzer',
#  'Mountain Cur',
#  'Mudi',
#  'Neapolitan Mastiff',
#  'Nederlandse Kooikerhondje',
#  'Newfoundland',
#  'Norfolk Terrier',
#  'Norrbottenspets',
#  'Norwegian Buhund',
#  'Norwegian Elkhound',
#  'Norwegian Lundehund',
#  'Norwich Terrier',
#  'Nova Scotia Duck Tolling Retriever',
#  'Old English Sheepdog',
#  'Otterhound',
#  'Papillon',
#  'Parson Russell Terrier',
#  'Pekingese',
#  'Pembroke Welsh Corgi',
#  'Perro de Presa Canario',
#  'Peruvian Inca Orchid',
#  'Petit Basset Griffon Vendéen',
#  'Pharaoh Hound',
#  'Plott Hound',
#  'Pointer',
#  'Polish Lowland Sheepdog',
#  'Pomeranian',
#  'Poodle (Miniature)',
#  'Poodle (Standard)',
#  'Poodle (Toy)',
#  'Porcelaine',
#  'Portuguese Podengo',
#  'Portuguese Podengo Pequeno',
#  'Portuguese Pointer',
#  'Portuguese Sheepdog',
#  'Portuguese Water Dog',
#  'Pudelpointer',
#  'Pug',
#  'Puli',
#  'Pumi',
#  'Pyrenean Mastiff',
#  'Pyrenean Shepherd',
#  'Rafeiro do Alentejo',
#  'Rat Terrier',
#  'Redbone Coonhound',
#  'Rhodesian Ridgeback',
#  'Romanian Mioritic Shepherd Dog',
#  'Rottweiler',
#  'Russell Terrier',
#  'Russian Toy',
#  'Russian Tsvetnaya Bolonka',
#  'Saint Bernard',
#  'Saluki',
#  'Samoyed',
#  'Schapendoes',
#  'Schipperke',
#  'Scottish Deerhound',
#  'Scottish Terrier',
#  'Sealyham Terrier',
#  'Segugio Italiano',
#  'Shetland Sheepdog',
#  'Shiba Inu',
#  'Shih Tzu',
#  'Shikoku',
#  'Siberian Husky',
#  'Silky Terrier',
#  'Skye Terrier',
#  'Sloughi',
#  'Slovakian Wirehaired Pointer',
#  'Slovensky Cuvac',
#  'Slovensky Kopov',
#  'Small Munsterlander Pointer',
#  'Smooth Fox Terrier',
#  'Soft Coated Wheaten Terrier',
#  'Spanish Mastiff',
#  'Spanish Water Dog',
#  'Spinone Italiano',
#  'Stabyhoun',
#  'Staffordshire Bull Terrier',
#  'Standard Schnauzer',
#  'Sussex Spaniel',
#  'Swedish Lapphund',
#  'Swedish Vallhund',
#  'Taiwan Dog',
#  'Teddy Roosevelt Terrier',
#  'Thai Ridgeback',
#  'Tibetan Mastiff',
#  'Tibetan Spaniel',
#  'Tibetan Terrier',
#  'Tornjak',
#  'Tosa',
#  'Toy Fox Terrier',
#  'Transylvanian Hound',
#  'Treeing Tennessee Brindle',
#  'Treeing Walker Coonhound',
#  'Vizsla',
#  'Weimaraner',
#  'Welsh Springer Spaniel',
#  'Welsh Terrier',
#  'West Highland White Terrier',
#  'Wetterhoun',
#  'Whippet',
#  'Wire Fox Terrier',
#  'Wirehaired Pointing Griffon',
#  'Wirehaired Vizsla',
#  'Working Kelpie',
#  'Xoloitzcuintli',
#  'Yakutian Laika',
#  'Yorkshire Terrier']

# %% [markdown]
# ## Menampilkan Kolom Temprament
# kolom temprament memiliki 129 nilai temprament yang unik, karena itu saya membuat kolom temprament_category untuk mengelompokkan temprament menjadi 10 kategori yang lebih umum yaitu: Friendly, Playful, Loyal, Confident, Intelligent, Gentle, Active, Calm, Indepentend, Brave

# %%
temperament_categories = {
    "Amiable": ["Friendly", "Outgoing", "Amiable", "Sociable", "Gregarious"],
    "Playful": ["Playful", "Mischievous", "Fun-Loving", "Lively", "Entertaining", "Energetic"],
    "Loyal": ["Loyal", "Devoted", "Faithful", "Dependable", "Obedient"],
    "Confident": ["Confident", "Self-Confident", "Fearless", "Bold", "Courageous", "Confident Guardian"],
    "Intelligent": ["Very Smart", "Quick", "Intelligent", "Smart", "Observant", "Keenly Observant"],
    "Gentle": ["Gentle", "Sweet-Tempered", "Sweet", "Gentlemanly", "Sweet-Natured"],
    "Active": ["Active", "Spirited", "Keen", "Active", "Vigilant", "Athletic"],
    "Low-Key": ["Calm", "Even-Tempered", "Low-Key"],
    "Independent": ["Independent", "Independent-Minded", "Strong-Willed"],
    "Brave": ["Brave", "Fearless"]
}

# %%
# Function to map temperament to the corresponding category
def map_temperament_category(temperament):
    if isinstance(temperament, float):
        return "Other"  # Handle float values
    for category, traits in temperament_categories.items():
        if any(trait in temperament for trait in traits):
            return category
    return "Other"

# Apply the mapping function to the "temperament" column
dataframe["temperament_category"] = dataframe["temperament"].apply(map_temperament_category)

# %%
dataframe = dataframe.dropna()
dataframe[['temperament', 'temperament_category']]
# Out:
#                                    temperament temperament_category
# 0          Confident, Famously Funny, Fearless            Confident
# 1    Dignified, Profoundly Loyal, Aristocratic                Loyal
# 2                 Friendly, Clever, Courageous              Amiable
# 3      Courageous, Dignified, Profoundly Loyal                Loyal
# 4                 Affectionate, Loyal, Playful              Playful
# ..                                         ...                  ...
# 270               Confident, Alert, Gregarious              Amiable
# 271               Friendly, Devoted, Trainable              Amiable
# 272                   Gentle, Loyal, Trainable                Loyal
# 274                         Loyal, Alert, Calm                Loyal
# 276         Affectionate, Sprightly, Tomboyish                Other
#
# [188 rows x 2 columns]

# %% [markdown]
# ## Menampilkan Data Kolom grooming_frequency_category
# Grooming frequency mengacu pada seberapa sering suatu hewan peliharaan perlu menjalani perawatan dan pemeliharaan rutin terkait kebersihan dan penampilan fisik mereka. Ini melibatkan kegiatan seperti menyisir bulu, mandi, memotong kuku, pembersihan telinga, dan lain sebagainya.

# %%
dataframe['grooming_frequency_category'].unique().tolist()
# dataframe['grooming_frequency_value'].unique().tolist()
# Out:
# ['2-3 Times a Week Brushing',
#  'Daily Brushing',
#  'Occasional Bath/Brush',
#  'Weekly Brushing',
#  'Specialty/Professional']

# %% [markdown]
# ## Menampilkan Data Kolom shedding_category
# Shedding category merujuk pada kategori atau tingkat kehilangan bulu pada hewan peliharaan. Ini menggambarkan seberapa banyak bulu hewan peliharaan rontok secara alami dalam suatu periode waktu tertentu.

# %%
dataframe['shedding_category'].unique().tolist()
# dataframe['shedding_value'].unique().tolist()
# Out:
# ['Seasonal', 'Infrequent', 'Occasional', 'Regularly', 'Frequent']

# %% [markdown]
# ## menampilkan data kolom energy_level_category

# %%
dataframe['energy_level_category'].unique().tolist()
# dataframe['energy_level_value'].unique().tolist()
# Out:
# ['Regular Exercise',
#  'Energetic',
#  'Needs Lots of Activity',
#  'Couch Potato',
#  'Calm']

# %% [markdown]
# ## menampilkan data trainability_category

# %%
dataframe['trainability_category'].unique().tolist()
# Out:
# ['Easy Training',
#  'May be Stubborn',
#  'Eager to Please',
#  'Independent',
#  'Agreeable']

# %% [markdown]
# ## menampilkan data demeanor_category

# %% [markdown]
# Demeanor category merujuk pada kategori atau karakteristik perilaku umum yang dimiliki oleh hewan peliharaan. Ini menggambarkan sifat atau sikap umum yang sering terlihat pada hewan peliharaan.
#
# Demeanor category umumnya digunakan untuk menggambarkan sifat atau sikap umum hewan peliharaan, terutama dalam interaksi dengan manusia dan lingkungan sekitarnya.

# %% [markdown]
# Temperament category mengacu pada sifat atau sikap bawaan yang mendasar yang cenderung konsisten pada hewan peliharaan sepanjang hidup mereka. Ini adalah sifat-sifat yang melekat pada individu dan cenderung dipengaruhi oleh faktor genetik. Contohnya dapat mencakup tingkat keberanian, keaktifan, kecerdasan, kepatuhan, dan kecenderungan terhadap perilaku tertentu. Temperament category dapat memberikan gambaran umum tentang kepribadian hewan peliharaan.
#
# Sementara itu, demeanor category lebih menggambarkan sikap dan perilaku umum yang sering terlihat pada hewan peliharaan dalam interaksi dengan manusia dan lingkungan sekitarnya. Ini dapat mencakup sifat-sifat seperti ramah, bermain, tenang, protektif, dan mandiri. Demeanor category lebih berfokus pada respons dan perilaku hewan peliharaan terhadap lingkungan sekitarnya dan interaksi dengan pemilik atau orang lain.
#
# Perbedaan utama antara temperament category dan demeanor category adalah bahwa temperament category lebih berkaitan dengan sifat bawaan dan karakteristik individu yang cenderung konsisten, sedangkan demeanor category lebih berkaitan dengan sikap dan perilaku umum yang terlihat dalam interaksi sehari-hari. Dalam konteks hewan peliharaan, keduanya dapat memberikan pemahaman yang lebih lengkap tentang sifat dan perilaku hewan peliharaan tersebut.

# %%
dataframe['demeanor_category'].unique().tolist()
# Out:
# ['Outgoing',
#  'Aloof/Wary',
#  'Friendly',
#  'Alert/Responsive',
#  'Reserved with Strangers']

# %% [markdown]
# ## Menampilkan Data Kolom Popularity

# %%
dataframe['popularity'].tolist()
# Out:
# ['148',
#  '113',
#  '60',
#  '47',
#  '58',
#  '175',
#  '122',
#  '186',
#  '85',
#  '166',
#  '90',
#  '55',
#  '17',
#  '140',
#  'of',
#  'of',
#  '87',
#  '39',
#  '6',
#  '127',
#  '124',
#  '43',
#  '125',
#  '106',
#  '187',
#  '144',
#  '22',
#  '46',
#  '138',
#  '118',
#  '49',
#  '130',
#  '121',
#  '35',
#  '88',
#  '103',
#  '21',
#  '84',
#  '11',
#  '100',
#  '132',
#  '26',
#  '98',
#  '62',
#  '5',
#  '51',
#  '69',
#  '179',
#  '32',
#  '68',
#  '18',
#  '185',
#  '45',
#  '33',
#  '79',
#  '64',
#  '190',
#  '75',
#  '183',
#  '143',
#  '30',
#  '38',
#  '81',
#  '162',
#  '12',
#  '56',
#  '176',
#  '17',
#  '67',
#  '52',
#  '188',
#  '94',
#  '27',
#  '135',
#  '157',
#  '149',
#  '161',
#  '184',
#  '91',
#  '4',
#  '134',
#  '2',
#  '9',
#  '63',
#  '174',
#  '3',
#  '115',
#  '177',
#  '16',
#  '66',
#  '74',
#  '145',
#  '189',
#  '24',
#  '152',
#  '155',
#  '77',
#  '159',
#  '76',
#  '73',
#  '104',
#  '95',
#  '173',
#  '163',
#  '1',
#  '99',
#  '147',
#  '93',
#  '71',
#  '168',
#  '37',
#  '133',
#  '133',
#  '29',
#  '34',
#  '110',
#  '70',
#  '19',
#  '102',
#  '150',
#  '40',
#  '126',
#  '165',
#  '97',
#  '191',
#  '108',
#  '83',
#  '72',
#  '182',
#  '54',
#  '117',
#  '92',
#  '13',
#  '156',
#  '172',
#  '171',
#  '114',
#  '170',
#  '23',
#  '7',
#  '7',
#  '154',
#  '50',
#  '28',
#  '160',
#  '151',
#  '181',
#  '86',
#  '142',
#  '41',
#  '8',
#  '82',
#  '48',
#  '120',
#  '59',
#  '105',
#  '158',
#  '57',
#  '164',
#  '25',
#  '44',
#  '20',
#  '14',
#  '112',
#  '178',
#  '192',
#  '123',
#  '53',
#  '153',
#  '80',
#  '89',
#  '180',
#  '169',
#  '131',
#  '119',
#  '96',
#  '111',
#  '137',
#  '31',
#  '36',
#  '107',
#  '42',
#  '61',
#  '101',
#  '65',
#  '167',
#  '140',
#  '10']

# %%
# Mengganti nilai 'of' dengan nilai yang valid
dataframe.loc[dataframe['popularity'] == 'of', 'popularity'] = 50

# %%
invalid_rows = dataframe[dataframe['popularity'] == 'of']
print(invalid_rows)
# Out:
# Empty DataFrame
# Columns: [breed, description, temperament, popularity, min_height, max_height, min_weight, max_weight, min_expectancy, max_expectancy, group, grooming_frequency_value, grooming_frequency_category, shedding_value, shedding_category, energy_level_value, energy_level_category, trainability_value, trainability_category, demeanor_value, demeanor_category, temperament_category]
# Index: []
#
# [0 rows x 22 columns]

# %%
dataframe['popularity'] = dataframe['popularity'].astype(int)

# %% [markdown]
# ## 2. Data Processing

# %% [markdown]
# ## Plotting Function

# %%
def plot(value_counts, title):
    plt.bar(value_counts.index, value_counts.values)
    plt.xlabel('Group')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=45) 
    plt.show()

# %% [markdown]
# ## Membuat Kolom Height, Weight, dan Expectancy

# %%
for col in ['height', 'weight', 'expectancy']:
    dataframe[col] = (dataframe['min_'+col] + dataframe['max_'+col]) / 2

# %%
dataframe[['height', 'min_height', 'max_height']].head()
# Out:
#    height  min_height  max_height
# 0  26.035       22.86       29.21
# 1  66.040       63.50       68.58
# 2  58.420       58.42       58.42
# 3  66.040       60.96       71.12
# 4  60.960       58.42       63.50

# %%
dataframe.head()
# Out:
#               breed                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament  popularity  min_height  \
# 0        Confident, Famously Funny, Fearless         148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic         113       63.50
# 2               Friendly, Clever, Courageous          60       58.42
# 3    Courageous, Dignified, Profoundly Loyal          47       60.96
# 4               Affectionate, Loyal, Playful          58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   energy_level_value  energy_level_category trainability_value  \
# 0                0.6       Regular Exercise                0.8
# 1                0.8              Energetic                0.2
# 2                0.6       Regular Exercise                1.0
# 3                0.8              Energetic                1.0
# 4                0.8              Energetic                0.4
#
#    trainability_category demeanor_value  demeanor_category  \
# 0          Easy Training            1.0           Outgoing
# 1        May be Stubborn            0.2         Aloof/Wary
# 2        Eager to Please            0.8           Friendly
# 3        Eager to Please            0.6   Alert/Responsive
# 4            Independent            0.8           Friendly
#
#   temperament_category  height     weight  expectancy
# 0            Confident  26.035   3.855535        13.5
# 1                Loyal  66.040  24.947580        13.5
# 2              Amiable  58.420  27.215542        12.5
# 3                Loyal  66.040  45.359237        11.5
# 4              Playful  60.960  36.287390        12.0
#
# [5 rows x 25 columns]

# %%
dataframe['group'].unique().tolist()
# Out:
# ['Toy Group',
#  'Hound Group',
#  'Terrier Group',
#  'Working Group',
#  'Non-Sporting Group',
#  'Sporting Group',
#  'Herding Group']

# %%
dataframe['group'].value_counts()
# Out:
# Hound Group           32
# Herding Group         30
# Sporting Group        29
# Working Group         29
# Terrier Group         27
# Toy Group             21
# Non-Sporting Group    20
# Name: group, dtype: int64

# %%
group_counts = dataframe['group'].value_counts()

plot(group_counts, 'Dog Group Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Height Menjadi 4 Kategori

# %%
dataframe['height_category'] = pd.cut(dataframe['height'],
                                      bins=[0, 30, 50, 70, float('inf')],
                                      labels=['Short', 'Medium', 'Tall', 'Very Tall'])
dataframe['height_category'].unique().tolist()
## display group with height category
dataframe[['group', 'height_category']].head(20)
# Out:
#                  group height_category
# 0            Toy Group           Short
# 1          Hound Group            Tall
# 2        Terrier Group            Tall
# 3        Working Group            Tall
# 4        Working Group            Tall
# 6          Hound Group            Tall
# 7   Non-Sporting Group          Medium
# 8          Hound Group            Tall
# 11       Terrier Group          Medium
# 12      Sporting Group          Medium
# 13       Working Group       Very Tall
# 15       Herding Group          Medium
# 17       Herding Group            Tall
# 19       Terrier Group           Short
# 20         Hound Group            Tall
# 21      Sporting Group            Tall
# 22         Hound Group          Medium
# 24         Hound Group          Medium
# 26         Hound Group          Medium
# 27       Herding Group            Tall

# %%
height_counts = dataframe['height_category'].value_counts()

plot(height_counts, 'Dog Height Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Weight Menjadi 4 Kategori

# %%
dataframe['weight_category'] = pd.cut(dataframe['weight'],
                                      bins=[0, 10, 30, 50, float('inf')],
                                      labels=['Light', 'Medium', 'Heavy', 'Very Heavy'])
default_weight_category = 'Medium'
dataframe['weight_category'] = dataframe['weight_category'].fillna(default_weight_category)

# %%
# count weight category
weights_counts = dataframe['weight_category'].value_counts()

plot(weights_counts, 'Dog Weight Distribution')

# %% [markdown]
# ## Mengkategorisasikan Kolom Expectancy Menjadi 4 Kategori

# %%
# Categorize expectancy
dataframe['expectancy_category'] = pd.cut(dataframe['max_expectancy'],
                                          bins=[0, 5, 10, 15, float('inf')],
                                          labels=['Short', 'Medium', 'Long', 'Very Long'])
dataframe['expectancy_category'] = dataframe['expectancy_category'].fillna('Short')
dataframe['expectancy_category'].unique().tolist()
dataframe['expectancy_category'].value_counts()
# Out:
# Long         146
# Very Long     26
# Medium        15
# Short          1
# Name: expectancy_category, dtype: int64

# %%
dataframe.dtypes
# Out:
# breed                            object
# description                      object
# temperament                      object
# popularity                        int32
# min_height                      float64
# max_height                      float64
# min_weight                      float64
# max_weight                      float64
# min_expectancy                  float64
# max_expectancy                  float64
# group                            object
# grooming_frequency_value        float64
# grooming_frequency_category      object
# shedding_value                  float64
# shedding_category                object
# energy_level_value              float64
# energy_level_category            object
# trainability_value              float64
# trainability_category            object
# demeanor_value                  float64
# demeanor_category                object
# temperament_category             object
# height                          float64
# weight                          float64
# expectancy                      float64
# height_category                category
# weight_category                category
# expectancy_category            category
# dtype: object

# %%
num_classes = len(dataframe['group'].unique())
print('Number of classes: {}'.format(num_classes))
# Out:
# Number of classes: 7

# %%
dataframe.isnull().sum()
# Out:
# breed                          0
# description                    0
# temperament                    0
# popularity                     0
# min_height                     0
# max_height                     0
# min_weight                     0
# max_weight                     0
# min_expectancy                 0
# max_expectancy                 0
# group                          0
# grooming_frequency_value       0
# grooming_frequency_category    0
# shedding_value                 0
# shedding_category              0
# energy_level_value             0
# energy_level_category          0
# trainability_value             0
# trainability_category          0
# demeanor_value                 0
# demeanor_category              0
# temperament_category           0
# height                         0
# weight                         0
# expectancy                     0
# height_category                0
# weight_category                0
# expectancy_category            0
# dtype: int64

# %% [markdown]
# ## 3. Training

# %%
## callbacks
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.95):
            print("\nReached 95% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

# %%
# Convert categorical columns to category type
categorical_cols = [
                    'trainability_category', 
                    'energy_level_category', 
                    'shedding_category',
                    'grooming_frequency_category', 
                    'weight_category',
                    'height_category',
                    'demeanor_category'
                    ]

dataframe[categorical_cols] = dataframe[categorical_cols].astype('category')



# Select the features and target variable
features = [
            'trainability_category', 
            'energy_level_category', 
            'shedding_category', 
            'grooming_frequency_category', 
            'temperament_category', 
            'weight_category',
            'height_category',
            'demeanor_category',
            ]


target = 'group'
X = dataframe[features]
y = dataframe[target]

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Create feature columns for categorical features
feature_columns = []
for col in categorical_cols:
    vocab = X[col].cat.categories.tolist()
    cat_column = tf.feature_column.categorical_column_with_vocabulary_list(col, vocab)
    emb_column = tf.feature_column.embedding_column(cat_column, dimension=8)
    feature_columns.append(emb_column)

# Create input functions for training and evaluation
def input_fn(features, labels, batch_size=32, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(features))
    dataset = dataset.batch(batch_size)
    return dataset

# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.DenseFeatures(feature_columns),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# model.summary()


# Compile the model
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
batch_size = 32
train_dataset = input_fn(X_train, y_train, batch_size=batch_size)
validation_dataset = input_fn(X_test, y_test, batch_size=batch_size, shuffle=False)
history = model.fit(train_dataset, validation_data=validation_dataset, epochs=100, callbacks=[callbacks])
# Out:
# Train for 5 steps, validate for 2 steps
# Epoch 1/100
# 5/5 [==============================] - 20s 4s/step - loss: 2.2535 - accuracy: 0.2200 - val_loss: 2.1035 - val_accuracy: 0.1842
# Epoch 2/100
# 5/5 [==============================] - 0s 83ms/step - loss: 1.6936 - accuracy: 0.3200 - val_loss: 1.9413 - val_accuracy: 0.1316
# Epoch 3/100
# 5/5 [==============================] - 0s 91ms/step - loss: 1.2860 - accuracy: 0.5533 - val_loss: 1.8412 - val_accuracy: 0.2105
# Epoch 4/100
# 5/5 [==============================] - 0s 86ms/step - loss: 1.2409 - accuracy: 0.5533 - val_loss: 1.7138 - val_accuracy: 0.2105
# Epoch 5/100
# 5/5 [==============================] - 0s 80ms/step - loss: 1.2114 - accuracy: 0.5333 - val_loss: 1.5562 - val_accuracy: 0.3684
# Epoch 6/100
# 5/5 [==============================] - 0s 87ms/step - loss: 1.1131 - accuracy: 0.6067 - val_loss: 1.7171 - val_accuracy: 0.2895
# Epoch 7/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.1041 - accuracy: 0.6200 - val_loss: 2.1348 - val_accuracy: 0.1842
# Epoch 8/100
# 5/5 [==============================] - 1s 149ms/step - loss: 1.1750 - accuracy: 0.5667 - val_loss: 2.4165 - val_accuracy: 0.2632
# Epoch 9/100
# 5/5 [==============================] - 1s 112ms/step - loss: 1.1059 - accuracy: 0.6400 - val_loss: 1.8411 - val_accuracy: 0.3421
# Epoch 10/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.8984 - accuracy: 0.6933 - val_loss: 1.9390 - val_accuracy: 0.2368
# Epoch 11/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.8742 - accuracy: 0.7067 - val_loss: 2.4245 - val_accuracy: 0.2368
# Epoch 12/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.8506 - accuracy: 0.6867 - val_loss: 4.0295 - val_accuracy: 0.1842
# Epoch 13/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8216 - accuracy: 0.7000 - val_loss: 2.4656 - val_accuracy: 0.2632
# Epoch 14/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.8055 - accuracy: 0.6933 - val_loss: 2.7330 - val_accuracy: 0.3158
# Epoch 15/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.8051 - accuracy: 0.7200 - val_loss: 1.9509 - val_accuracy: 0.4474
# Epoch 16/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6287 - accuracy: 0.7933 - val_loss: 2.5636 - val_accuracy: 0.3684
# Epoch 17/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.8094 - accuracy: 0.7333 - val_loss: 2.4637 - val_accuracy: 0.3421
# Epoch 18/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6447 - accuracy: 0.7867 - val_loss: 2.9203 - val_accuracy: 0.3158
# Epoch 19/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.5645 - accuracy: 0.8067 - val_loss: 2.6561 - val_accuracy: 0.2632
# Epoch 20/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.5088 - accuracy: 0.8267 - val_loss: 2.7610 - val_accuracy: 0.3684
# Epoch 21/100
# 5/5 [==============================] - 1s 200ms/step - loss: 0.5375 - accuracy: 0.8667 - val_loss: 2.8442 - val_accuracy: 0.3947
# Epoch 22/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5019 - accuracy: 0.8467 - val_loss: 2.2773 - val_accuracy: 0.4211
# Epoch 23/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.5147 - accuracy: 0.8333 - val_loss: 2.5588 - val_accuracy: 0.3684
# Epoch 24/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3780 - accuracy: 0.8800 - val_loss: 3.2360 - val_accuracy: 0.3684
# Epoch 25/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.5309 - accuracy: 0.8200 - val_loss: 3.0168 - val_accuracy: 0.2632
# Epoch 26/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2543 - accuracy: 0.9200 - val_loss: 2.2950 - val_accuracy: 0.4211
# Epoch 27/100
# 3/5 [=================>............] - ETA: 0s - loss: 0.1782 - accuracy: 0.9688
# Reached 95% accuracy so cancelling training!
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2375 - accuracy: 0.9533 - val_loss: 3.7980 - val_accuracy: 0.3421

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_features_15 (DenseFeat multiple                  264
# _________________________________________________________________
# dense_102 (Dense)            multiple                  29184
# _________________________________________________________________
# batch_normalization_84 (Batc multiple                  2048
# _________________________________________________________________
# dense_103 (Dense)            multiple                  131328
# _________________________________________________________________
# batch_normalization_85 (Batc multiple                  1024
# _________________________________________________________________
# dense_104 (Dense)            multiple                  32896
# _________________________________________________________________
# batch_normalization_86 (Batc multiple                  512
# _________________________________________________________________
# dense_105 (Dense)            multiple                  8256
# _________________________________________________________________
# batch_normalization_87 (Batc multiple                  256
# _________________________________________________________________
# dense_106 (Dense)            multiple                  2080
# _________________________________________________________________
# batch_normalization_88 (Batc multiple                  128
# _________________________________________________________________
# dense_107 (Dense)            multiple                  528
# _________________________________________________________________
# batch_normalization_89 (Batc multiple                  64
# _________________________________________________________________
# dense_108 (Dense)            multiple                  119
# =================================================================
# Total params: 208,687
# Trainable params: 206,671
# Non-trainable params: 2,016
# _________________________________________________________________

# %%
# Evaluasi model
test_dataset = input_fn(X_test, y_test, batch_size=batch_size, shuffle=False)
_, accuracy = model.evaluate(test_dataset)
print("Akurasi: ", accuracy)
# Out:
# 2/2 [==============================] - 0s 17ms/step - loss: 3.7980 - accuracy: 0.3421
# Akurasi:  0.34210527

# %%
# Get training and validation accuracy values
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot training and validation accuracy
epochs = range(1, len(train_acc) + 1)
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Get training and validation accuracy values
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
epochs = range(1, len(train_acc) + 1)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Create a new dataframe with input features for prediction

new_data = pd.DataFrame({
    "trainability_category": ["Eager to Please"],
  "energy_level_category": ["Needs Lots of Activity"],
  "shedding_category": ["Frequent"],
  "grooming_frequency_category": ["Weekly Brushing"],
  "temperament_category": ["Loyal"],
  "weight_category": ["Heavy"],
  "height_category": ["Tall"],
  "demeanor_category": ["Friendly"]
})


# Convert the new data to individual arrays for prediction
new_data_arrays = [new_data[feature].values.reshape(-1, 1) for feature in [
    'trainability_category', 
    'energy_level_category', 
    'shedding_category', 
    'grooming_frequency_category', 
    'temperament_category', 
    'weight_category',
    'height_category',
    'demeanor_category',
    ]
    ]

# Make predictions on the new data
predictions = model.predict(new_data_arrays)

# Decode the predicted breed labels
predicted_labels = np.argmax(predictions, axis=1)
predicted_labels = label_encoder.inverse_transform(predicted_labels)

# Menampilkan hasil prediksi
for label in predicted_labels:
    print(label)
    breeds = dataframe.loc[dataframe['group'] == label]
     # Sort by popularity in descending order
    breeds = breeds.sort_values('popularity', ascending=False)
    # Get top 5 breeds
    top_breeds = breeds.head(5)
    # print(top_breeds)
    # print('\n')

pd.DataFrame(breeds)
# Out:
# Herding Group
#                            breed  \
# 34           Bergamasco Sheepdog
# 209            Pyrenean Shepherd
# 64                    Canaan Dog
# 193      Polish Lowland Sheepdog
# 250             Swedish Vallhund
# 176             Norwegian Buhund
# 107             Finnish Lapphund
# 206                         Puli
# 103     Entlebucher Mountain Dog
# 134           Icelandic Sheepdog
# 243            Spanish Water Dog
# 207                         Pumi
# 35                 Berger Picard
# 56                        Briard
# 27                Bearded Collie
# 32              Belgian Sheepdog
# 28                     Beauceron
# 33              Belgian Tervuren
# 50          Bouvier des Flandres
# 181         Old English Sheepdog
# 66          Cardigan Welsh Corgi
# 15         Australian Cattle Dog
# 31              Belgian Malinois
# 82                        Collie
# 46                 Border Collie
# 165  Miniature American Shepherd
# 228            Shetland Sheepdog
# 17           Australian Shepherd
# 186         Pembroke Welsh Corgi
# 114          German Shepherd Dog
#
#                                            description  \
# 34   Beneath the one-of-a-kind coat is a large, mus...
# 209  These tough, lean, and lively herders, famous ...
# 64   Canaan Dogs are lean, bushy-tailed dogs standi...
# 193  First, about that nickname: PON is the acronym...
# 250  With their thick sable coat, sturdy constructi...
# 176  The Buhund, a prototypical spitz, provides a g...
# 107  Finnish Lapphunds, with their luscious coat, s...
# 206  First, there are those dreadlocks, the instant...
# 103  Entlebucher (ENT-leh-boo-cur) Mountain Dogs ar...
# 134  Icelandics are one of the 50 or so northern br...
# 243  The unique look of these inexhaustible workers...
# 207  The Pumi (POO-mee; plural Pumik) was conceived...
# 35   You can spot a Berger Picard a mile away thank...
# 56   Briards are herders known for a wavy coat of e...
# 27   Standing 20 to 22 inches at the shoulder and c...
# 32   The stirring silhouette of a Belgian Sheepdog ...
# 28   Beaucerons are muscular, rugged, and large, st...
# 33   The Belgian Tervuren is characterized by a str...
# 50   Standing as high as 27.5 inches, with heavy bo...
# 181  Beneath the Old English Sheepdog’s profuse dou...
# 66   Long, low-set dogs with sturdy bone, short leg...
# 15   Standing between 17 to 20 inches at the should...
# 31   Belgian Malinois are squarely built, proud, an...
# 82   The Collie is a large but lithe herder standin...
# 46   Borders are athletic, medium-sized herders sta...
# 165  The Miniature American Shepherd shares many ph...
# 228  The Shetland Sheepdog is a small, active, and ...
# 17   The Australian Shepherd, the cowboy’s herding ...
# 186  At 10 to 12 inches at the shoulder and 27 to 3...
# 114  German Shepherd Dogs can stand as high as 26 i...
#
#                                            temperament  popularity  \
# 34                  Independent, Sociable, Intelligent         187
# 209                 Affectionate, Active, Enthusiastic         181
# 64                          Confident, Alert, Vigilant         179
# 193                          Confident, Clever, Lively         170
# 250                      Friendly, Energetic, Watchful         169
# 176                       Confident, Smart, Perceptive         165
# 107                             Friendly, Alert, Agile         161
# 206                          Loyal, Smart, Home-Loving         160
# 103                         Loyal, Smart, Enthusiastic         157
# 134                     Friendly, Playful, Inquisitive         155
# 243  Playful but also Work-Oriented. Very Active an...         153
# 207                   Energetic, Lively, Ready to Work         151
# 35                      Loyal, Good-Natured, Observant         144
# 56                          Confident, Smart, Faithful         132
# 27                          Smart, Bouncy, Charismatic         127
# 32                    Bright, Watchful, Serious-Minded         125
# 28                          Gentle, Faithful, Obedient         124
# 33                      Courageous, Alert, Intelligent         106
# 50             Affectionate, Courageous, Strong-Willed          84
# 181                           Adaptable, Gentle, Smart          72
# 66                          Affectionate, Loyal, Smart          68
# 15                            Alert, Curious, Pleasant          55
# 31                       Confident, Smart, Hardworking          43
# 82                            Devoted, Graceful, Proud          38
# 46                      Affectionate, Smart, Energetic          35
# 165                 Good-Natured, Intelligent, Devoted          34
# 228                         Playful, Energetic, Bright          25
# 17                     Smart, Work-Oriented, Exuberant          17
# 186                         Affectionate, Smart, Alert          13
# 114                       Confident, Courageous, Smart           2
#
#      min_height  max_height  min_weight  max_weight  min_expectancy  \
# 34       55.880      59.690   25.854765   38.101759            13.0
# 209      38.100      53.340    6.803886   13.607771             0.0
# 64       48.260      60.960   15.875733   24.947580            12.0
# 193      43.180      50.800   13.607771   22.679619            12.0
# 250      29.210      34.925    9.071847   15.875733            12.0
# 176      40.640      46.990   11.793402   18.143695            12.0
# 107      40.640      53.340   14.968548   24.040396            12.0
# 206      40.640      43.180   11.339809   15.875733            10.0
# 103      40.640      53.340   18.143695   29.483504            11.0
# 134      41.910      45.720   11.339809   13.607771            12.0
# 243      40.005      50.165   14.061363   22.226026            12.0
# 207      38.100      46.990    9.979032   13.154179            12.0
# 35       54.610      64.770   22.679619   31.751466            12.0
# 56       55.880      68.580   24.947580   45.359237            12.0
# 27       50.800      55.880   20.411657   24.947580            12.0
# 32       55.880      66.040   20.411657   34.019428            12.0
# 28       60.960      69.850   31.751466   49.895161            10.0
# 33       55.880      66.040   20.411657   34.019428            12.0
# 50       59.690      69.850   31.751466   49.895161            10.0
# 181      53.340      55.880   27.215542   45.359237            10.0
# 66       26.670      31.750   11.339809   17.236510            12.0
# 15       43.180      50.800   15.875733   22.679619            12.0
# 31       55.880      66.040   18.143695   36.287390            14.0
# 82       55.880      66.040   22.679619   34.019428            12.0
# 46       45.720      55.880   13.607771   24.947580            12.0
# 165      33.020      45.720    9.071847   18.143695            12.0
# 228      33.020      40.640    6.803886   11.339809            12.0
# 17       45.720      58.420   18.143695   29.483504            12.0
# 186      25.400      30.480   12.700586   13.607771            12.0
# 114      55.880      66.040   22.679619   40.823313             7.0
#
#      max_expectancy  ... trainability_category  demeanor_value  \
# 34             15.0  ...             Agreeable             0.4
# 209             0.0  ...             Agreeable             0.4
# 64             15.0  ...           Independent             0.4
# 193            14.0  ...       May be Stubborn             0.2
# 250            15.0  ...       Eager to Please             0.8
# 176            15.0  ...         Easy Training             0.8
# 107            15.0  ...       Eager to Please             0.4
# 206            15.0  ...           Independent             0.4
# 103            13.0  ...           Independent             0.4
# 134            14.0  ...       Eager to Please             0.8
# 243            14.0  ...       Eager to Please             0.4
# 207            13.0  ...         Easy Training             0.6
# 35             13.0  ...         Easy Training             0.6
# 56             12.0  ...           Independent             0.4
# 27             14.0  ...           Independent             1.0
# 32             14.0  ...         Easy Training             0.4
# 28             12.0  ...         Easy Training             0.4
# 33             14.0  ...         Easy Training             0.4
# 50             12.0  ...             Agreeable             0.6
# 181            12.0  ...           Independent             0.6
# 66             15.0  ...             Agreeable             0.6
# 15             16.0  ...       May be Stubborn             0.4
# 31             16.0  ...         Easy Training             0.4
# 82             14.0  ...         Easy Training             0.8
# 46             15.0  ...       Eager to Please             0.4
# 165            13.0  ...       Eager to Please             0.8
# 228            14.0  ...       Eager to Please             0.4
# 17             15.0  ...       Eager to Please             0.6
# 186            13.0  ...             Agreeable             1.0
# 114            10.0  ...       Eager to Please             0.6
#
#            demeanor_category  temperament_category   height     weight  \
# 34   Reserved with Strangers               Amiable  57.7850  31.978262
# 209  Reserved with Strangers                Active  45.7200  10.205828
# 64   Reserved with Strangers             Confident  54.6100  20.411657
# 193               Aloof/Wary               Playful  46.9900  18.143695
# 250                 Friendly               Amiable  32.0675  12.473790
# 176                 Friendly             Confident  43.8150  14.968548
# 107  Reserved with Strangers               Amiable  46.9900  19.504472
# 206  Reserved with Strangers                 Loyal  41.9100  13.607771
# 103  Reserved with Strangers                 Loyal  46.9900  23.813599
# 134                 Friendly               Amiable  43.8150  12.473790
# 243  Reserved with Strangers               Playful  45.0850  18.143695
# 207         Alert/Responsive               Playful  42.5450  11.566605
# 35          Alert/Responsive                 Loyal  59.6900  27.215542
# 56   Reserved with Strangers                 Loyal  62.2300  35.153409
# 27                  Outgoing           Intelligent  53.3400  22.679619
# 32   Reserved with Strangers                 Other  60.9600  27.215542
# 28   Reserved with Strangers                 Loyal  65.4050  40.823313
# 33   Reserved with Strangers             Confident  60.9600  27.215542
# 50          Alert/Responsive             Confident  64.7700  40.823313
# 181         Alert/Responsive           Intelligent  54.6100  36.287390
# 66          Alert/Responsive                 Loyal  29.2100  14.288160
# 15   Reserved with Strangers                 Other  46.9900  19.277676
# 31   Reserved with Strangers             Confident  60.9600  27.215542
# 82                  Friendly                 Loyal  60.9600  28.349523
# 46   Reserved with Strangers               Playful  50.8000  19.277676
# 165                 Friendly                 Loyal  39.3700  13.607771
# 228  Reserved with Strangers               Playful  36.8300   9.071847
# 17          Alert/Responsive           Intelligent  52.0700  23.813599
# 186                 Outgoing           Intelligent  27.9400  13.154179
# 114         Alert/Responsive             Confident  60.9600  31.751466
#
#     expectancy  height_category weight_category  expectancy_category
# 34        14.0             Tall           Heavy                 Long
# 209        0.0           Medium          Medium                Short
# 64        13.5             Tall          Medium                 Long
# 193       13.0           Medium          Medium                 Long
# 250       13.5           Medium          Medium                 Long
# 176       13.5           Medium          Medium                 Long
# 107       13.5           Medium          Medium                 Long
# 206       12.5           Medium          Medium                 Long
# 103       12.0           Medium          Medium                 Long
# 134       13.0           Medium          Medium                 Long
# 243       13.0           Medium          Medium                 Long
# 207       12.5           Medium          Medium                 Long
# 35        12.5             Tall          Medium                 Long
# 56        12.0             Tall           Heavy                 Long
# 27        13.0             Tall          Medium                 Long
# 32        13.0             Tall          Medium                 Long
# 28        11.0             Tall           Heavy                 Long
# 33        13.0             Tall          Medium                 Long
# 50        11.0             Tall           Heavy                 Long
# 181       11.0             Tall           Heavy                 Long
# 66        13.5            Short          Medium                 Long
# 15        14.0           Medium          Medium            Very Long
# 31        15.0             Tall          Medium            Very Long
# 82        13.0             Tall          Medium                 Long
# 46        13.5             Tall          Medium                 Long
# 165       12.5           Medium          Medium                 Long
# 228       13.0           Medium           Light                 Long
# 17        13.5             Tall          Medium                 Long
# 186       12.5            Short          Medium                 Long
# 114        8.5             Tall           Heavy               Medium
#
# [30 rows x 28 columns]

# %%
# new_data.to_json('new_data.json', orient='records', lines=False)

# %%
print(new_data_arrays)
# Out:
# [array([['Eager to Please']], dtype=object), array([['Needs Lots of Activity']], dtype=object), array([['Frequent']], dtype=object), array([['Weekly Brushing']], dtype=object), array([['Loyal']], dtype=object), array([['Heavy']], dtype=object), array([['Tall']], dtype=object), array([['Friendly']], dtype=object)]

# %% [markdown]
# ## Save the Model

# %%
# tf.saved_model.save(model, './model')

# %%
# Save the model
# model.save('./model/model.h5')

# %%
# Save the LabelEncoder
# np.save('./model/label_encoder.npy', label_encoder.classes_)
